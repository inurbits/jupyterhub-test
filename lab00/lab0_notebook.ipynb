# %% [markdown]
# # Lab 0: Environment Setup and JupyterHub Orientation
# **CMSC395 — Computer Networks**
# Estimated time: 45–60 minutes | Points: 5 (completion)
#
# ---
#
# This notebook accompanies the Lab 0 document. Work through each cell in order.
# Run a cell with **Shift+Enter**. Read the output before moving to the next cell.
#
# > **Submission:** Push this completed notebook to your GitHub Classroom repository before the deadline.
# > Use `Kernel → Restart Kernel and Run All Cells` before your final push to ensure clean output.

# %% [markdown]
# ---
# ## Part 3: Notebook Basics

# %% [markdown]
# ### Cell 3.1 — Code — Hello, notebook
# *This cell is pre-written. Run it with Shift+Enter and confirm you see output.*

# %%
# Pre-written — run this cell and confirm the output before continuing.
print("Hello from CS441!")
print("Your environment is working.")

import sys
print(f"Python version: {sys.version}")

# %% [markdown]
# ### Cell 3.2 — Markdown — Introduce yourself
#
# *Double-click this cell to edit it. Replace the placeholder text below with your own introduction (2–3 sentences: your name, your year, and one thing you hope to learn from this course). Press Shift+Enter to render it when you are done.*
#
# ---
#
# **Your introduction:**
#
# *(Write here — replace this line)*

# %% [markdown]
# ### Cell 3.3 — Code — Simple Python warm-up
#
# *Write a function called `summarize_path(hops)` that takes a list of IP address strings and returns a formatted string showing the path.*
#
# *Example:*
# ```python
# summarize_path(['10.0.0.1', '172.16.0.1', '8.8.8.8'])
# # → '10.0.0.1 -> 172.16.0.1 -> 8.8.8.8 (3 hops)'
# ```
#
# *Call your function with at least two different inputs and print the results.*

# %%
# Cell 3.3 — implement summarize_path() and call it with two examples

def summarize_path(hops):
    # Your code here
    pass


# Call your function with at least two different inputs
# Example 1:


# Example 2:

# %% [markdown]
# ---
# ## Part 4: Verifying Installed Packages
#
# Run the cell below to confirm all Python packages used in this course are available.
# If any import fails, contact the instructor before continuing.

# %%
# Package verification — do not modify this cell
packages = [
    ("scapy",      "scapy"),
    ("pyshark",    "pyshark"),
    ("numpy",      "numpy"),
    ("matplotlib", "matplotlib"),
    ("requests",   "requests"),
]

all_ok = True
for display_name, import_name in packages:
    try:
        __import__(import_name)
        print(f"  ✓  {display_name}")
    except ImportError:
        print(f"  ✗  {display_name}  ← NOT FOUND — contact instructor")
        all_ok = False

print()
if all_ok:
    print("All packages verified. You are ready for Lab 1.")
else:
    print("One or more packages are missing. Do not continue until this is resolved.")

# %% [markdown]
# ### Terminal verification
#
# The cell above checks Python packages. You also need to verify the command-line tools in the **terminal** (open one from the Launcher). Run each of these commands and confirm they produce output without an error:
#
# ```bash
# ping -c 3 8.8.8.8
# tshark --version | head -1
# dig +short google.com
# nc -h 2>&1 | head -3
# ```
#
# Use the cell below to record what you observed.

# %% [markdown]
# ### Cell 4.2 — Markdown — Terminal verification notes
#
# *Double-click this cell and fill in the table. Replace each `—` with the first line of output you saw, or `NOT FOUND` if the command failed.*
#
# | Command | Output (first line) | Status |
# |---|---|---|
# | `ping -c 3 8.8.8.8` | — | |
# | `tshark --version` | — | |
# | `dig +short google.com` | — | |
# | `nc -h` | — | |

# %% [markdown]
# ---
# ## Part 5: Git Workflow
#
# Complete the Git steps (clone, configure, commit, push) in the **terminal** as described in the lab document.
# Come back here and complete the cell below after your first push.

# %% [markdown]
# ### Cell 5.1 — Markdown — Git confirmation
#
# *Double-click and fill in the details below after completing your first commit and push.*
#
# **GitHub repository URL:**
# *(paste your repo URL here)*
#
# **Commit message used:**
# *(paste the message here)*
#
# **Commit visible on github.com?**
# *(Yes / No)*

# %% [markdown]
# ---
# ## Part 6: Final Check
#
# Before your final push:
#
# 1. Use **Kernel → Restart Kernel and Run All Cells** to confirm the notebook runs cleanly from top to bottom
# 2. Check that all cells have output and no errors
# 3. Complete the checklist below
# 4. Push with the commit message: `Lab0 final submission`

# %% [markdown]
# ### Cell 6.1 — Markdown — Submission checklist
#
# *Double-click and replace each `[ ]` with `[x]` when the item is complete.*
#
# - [ ] JupyterHub login confirmed — server started without errors
# - [ ] GitHub Classroom repository accepted and cloned
# - [ ] Git configured with my name and email
# - [ ] Cell 3.1 runs and shows Python version
# - [ ] Cell 3.2 contains my introduction (rendered as Markdown)
# - [ ] Cell 3.3 implements `summarize_path()` with two examples
# - [ ] Package verification cell shows all packages OK
# - [ ] Terminal tools (tshark, ping, dig, nc) all run without errors
# - [ ] Terminal verification table in Cell 4.2 is filled in
# - [ ] Git confirmation in Cell 5.1 is filled in
# - [ ] Notebook runs cleanly with Restart and Run All
# - [ ] At least 2 commits visible in GitHub repository history

# %% [markdown]
# ---
# *CMSC395 Computer Networks — Lab 0*
# *Push this notebook to your GitHub Classroom repository with the message: `Lab0 final submission`*
